# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

import random
from random import seed
from random import sample

tensorflow.test.gpu_device_name()

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
title = "SWaT_Dataset_Normal_v0"
df = pd.read_csv("/content/drive/MyDrive/CI Project/" + title + ".csv")
df
# Out:
#                      Timestamp    FIT101    LIT101  MV101  P101  P102  \
# 0        22/12/2015 4:00:00 PM  2.470294  261.5804      2     2     1
# 1        22/12/2015 4:00:01 PM  2.457163  261.1879      2     2     1
# 2        22/12/2015 4:00:02 PM  2.439548  260.9131      2     2     1
# 3        22/12/2015 4:00:03 PM  2.428338  260.2850      2     2     1
# 4        22/12/2015 4:00:04 PM  2.424815  259.8925      2     2     1
# ...                        ...       ...       ...    ...   ...   ...
# 496795   28/12/2015 9:59:55 AM  2.460366  523.0430      2     2     1
# 496796   28/12/2015 9:59:56 AM  2.448836  522.9645      2     2     1
# 496797   28/12/2015 9:59:57 AM  2.434744  522.8860      2     2     1
# 496798   28/12/2015 9:59:58 AM  2.428338  522.9252      2     2     1
# 496799   28/12/2015 9:59:59 AM  2.427057  522.8467      2     2     1
#
#           AIT201    AIT202    AIT203    FIT201  ...  P501  P502     PIT501  \
# 0       244.3284  8.190080  306.1010  2.471278  ...     1     1   10.02948
# 1       244.3284  8.190080  306.1010  2.468587  ...     1     1   10.02948
# 2       244.3284  8.190080  306.1010  2.467305  ...     1     1   10.02948
# 3       244.3284  8.190080  306.1010  2.466536  ...     1     1   10.02948
# 4       244.4245  8.190080  306.1010  2.466536  ...     1     1   10.02948
# ...          ...       ...       ...       ...  ...   ...   ...        ...
# 496795  262.0161  8.396437  328.5055  2.442316  ...     2     1  250.81710
# 496796  262.0161  8.396437  328.5055  2.442316  ...     2     1  250.81710
# 496797  262.0161  8.396437  328.6337  2.444879  ...     2     1  250.81710
# 496798  262.0161  8.396437  328.6337  2.445391  ...     2     1  250.81710
# 496799  262.0161  8.396437  328.6337  2.445391  ...     2     1  250.86520
#
#           PIT502      PIT503    FIT601  P601  P602  P603  Normal/Attack
# 0       0.000000    4.277749  0.000256     1     1     1         Normal
# 1       0.000000    4.277749  0.000256     1     1     1         Normal
# 2       0.000000    4.277749  0.000256     1     1     1         Normal
# 3       0.000000    4.277749  0.000256     1     1     1         Normal
# 4       0.000000    4.277749  0.000256     1     1     1         Normal
# ...          ...         ...       ...   ...   ...   ...            ...
# 496795  1.778105  189.855200  0.000128     1     1     1         Normal
# 496796  1.778105  189.502700  0.000128     1     1     1         Normal
# 496797  1.778105  189.502700  0.000128     1     1     1         Normal
# 496798  1.649953  189.502700  0.000128     1     1     1         Normal
# 496799  1.649953  189.598800  0.000128     1     1     1         Normal
#
# [496800 rows x 53 columns]

# %%
df.fillna(0, inplace=True)
df = df[15000:]
df = df.drop(columns=[' Timestamp'])
df = df.drop(columns=['Normal/Attack'])
df
# Out:
#           FIT101    LIT101  MV101  P101  P102    AIT201    AIT202    AIT203  \
# 15000   2.670147  651.2425      2     2     1  262.2404  8.386824  495.0269
# 15001   2.643564  651.7136      2     2     1  262.2404  8.386824  494.6680
# 15002   2.623387  651.9883      2     2     1  262.2404  8.386824  494.6680
# 15003   2.609935  652.3023      2     2     1  262.2404  8.386824  494.6680
# 15004   2.600327  652.4201      2     2     1  262.2404  8.388105  494.3860
# ...          ...       ...    ...   ...   ...       ...       ...       ...
# 496795  2.460366  523.0430      2     2     1  262.0161  8.396437  328.5055
# 496796  2.448836  522.9645      2     2     1  262.0161  8.396437  328.5055
# 496797  2.434744  522.8860      2     2     1  262.0161  8.396437  328.6337
# 496798  2.428338  522.9252      2     2     1  262.0161  8.396437  328.6337
# 496799  2.427057  522.8467      2     2     1  262.0161  8.396437  328.6337
#
#           FIT201  MV201  ...    FIT504  P501  P502    PIT501    PIT502  \
# 15000   2.471022      2  ...  0.310604     2     1  253.4286  1.361612
# 15001   2.471022      2  ...  0.310604     2     1  253.4286  1.361612
# 15002   2.471022      2  ...  0.309067     2     1  253.4286  1.361612
# 15003   2.471022      2  ...  0.308619     2     1  253.4286  1.361612
# 15004   2.471022      2  ...  0.308619     2     1  253.4286  1.361612
# ...          ...    ...  ...       ...   ...   ...       ...       ...
# 496795  2.442316      2  ...  0.308619     2     1  250.8171  1.778105
# 496796  2.442316      2  ...  0.308619     2     1  250.8171  1.778105
# 496797  2.444879      2  ...  0.308619     2     1  250.8171  1.778105
# 496798  2.445391      2  ...  0.308619     2     1  250.8171  1.649953
# 496799  2.445391      2  ...  0.307786     2     1  250.8652  1.649953
#
#           PIT503    FIT601  P601  P602  P603
# 15000   192.6589  0.000128     1     1     1
# 15001   192.6589  0.000128     1     1     1
# 15002   192.6589  0.000128     1     1     1
# 15003   192.6589  0.000128     1     1     1
# 15004   192.6589  0.000128     1     1     1
# ...          ...       ...   ...   ...   ...
# 496795  189.8552  0.000128     1     1     1
# 496796  189.5027  0.000128     1     1     1
# 496797  189.5027  0.000128     1     1     1
# 496798  189.5027  0.000128     1     1     1
# 496799  189.5988  0.000128     1     1     1
#
# [481800 rows x 51 columns]

# %%
s1_df = df[['FIT101', 'LIT101', 'MV101', 'P101', 'P102']]
s2_df = df[['AIT201', 'AIT202', 'AIT203', 'FIT201', 'MV201', 'P201', 'P202', 'P203', 'P204', 'P205', 'P206']]
s3_df = df[['FIT301', 'LIT301', 'MV301', 'MV302', 'MV303', 'MV304', 'P301', 'P302']]
s4_df = df[['AIT401', 'AIT402', 'FIT401', 'LIT401', 'P401', 'P402', 'P403', 'P404', 'UV401']]
s5_df = df[['AIT501', 'AIT502', 'AIT503', 'AIT504', 'FIT501', 'FIT502', 'FIT503', 'FIT504', 'P501', 'P502', 'PIT501', 'PIT502', 'PIT503']]
s6_df = df[['FIT601', 'P601', 'P602', 'P603']]

# %%
def mergeDfs(df1, df2):
  return pd.merge(df1, df2, left_index=True, right_index=True)

# %%
def transformData(df):
    # Scale and transform the data
    for i in df.select_dtypes('object').columns:
        le = LabelEncoder().fit(df[i])
        df[i] = le.transform(df[i])

    x_scaler = MinMaxScaler()
    x_data = x_scaler.fit_transform(df)

    return x_data, x_scaler

# %%
def windowing_and_splitting(dataset, start, train, vali, window, horizon):
    # Window and split the data
    x_dataset = []
    y_dataset = []
    x_train = []
    y_train = []
    x_vali = []
    y_vali = []
    x_test = []
    y_test = []

    end = len(dataset)

    for i in range(start, end-5):
        indices = range(i, i+window)
        x_dataset.append(dataset[indices])
        indicey = range(i+window, i+1+window)
        y_dataset.append(dataset[i+window])

    temp = list(zip(x_dataset, y_dataset))
    random.shuffle(temp)
    res1, res2 = zip(*temp)

    for i in range(start, train):
        x_train.append(res1[i])
        y_train.append(res2[i])

    for i in range(train, vali):
        x_vali.append(res1[i])
        y_vali.append(res2[i])
    for i in range(vali, len(dataset)-5):
        x_test.append(res1[i])
        y_test.append(res2[i])

    return (
        np.array(x_train),
        np.array(y_train),
        np.array(x_vali),
        np.array(y_vali),
        np.array(x_test),
        np.array(y_test)
    )

# %%
hist_window = 5
horizon = 1
TRAIN_SPLIT = 400000
VALI_SPLIT = 450000

# %%
def trainModel(df, name):
  x_data, scaler = transformData(df)
  x_train, y_train, x_vali, y_vali, x_test, y_test, = windowing_and_splitting(x_data, 0, TRAIN_SPLIT, VALI_SPLIT, hist_window, horizon)

  model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(20, input_shape=(x_train.shape[1], x_train.shape[2])),
    tf.keras.layers.Dense(len(x_data[0]))
  ])
  model.compile(optimizer='adam', loss='mse')
  model.summary()
  print(model)

  model_path = 'sequential_7.h5'
  early_stopings = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='min')
  checkpoint = tf.keras.callbacks.ModelCheckpoint(model_path, monitor='val_loss', save_best_only=True, mode='min', verbose=0)
  callbacks = [early_stopings,checkpoint]
  history = model.fit(x_train, y_train,epochs=25,steps_per_epoch=100,validation_data=(x_vali, y_vali),validation_steps=50,verbose=0,callbacks=callbacks)

  # plt.figure(figsize=(16,9))
  # plt.plot(history.history['loss'])
  # plt.plot(history.history['val_loss'])
  # plt.title('Training Loss over Time')
  # plt.ylabel('Loss')
  # plt.xlabel('Epoch')
  # plt.legend(['Training Loss', 'Validation Loss'])
  # plt.show()

  # loss = model.evaluate(x_train, y_train)
  # print(f"Loss: {loss}")

  model.save("/content/drive/MyDrive/CI Project/Cascade_Model/Cascade_" + name + ".h5")
  return model

# %%
def getPredictions(df, model):
    x_data, scaler = transformData(df)
    x_normal = []
    y_normal = []

    for i in range(len(x_data) - 5):
        indices = range(i, i + 5)
        x_normal.append(x_data[indices])
        y_normal.append(x_data[i + 5])

    x_normal = np.array(x_normal)
    y_normal = np.array(y_normal)

    predictions_scaled = model.predict(x_normal)

    # Unscale the predictions
    predictions_unscaled = scaler.inverse_transform(predictions_scaled)

    return predictions_scaled, predictions_unscaled

# %% [markdown]
# ## Predict for Stage 1 using Stage 6

# %%
s6_s1_model = trainModel(mergeDfs(s6_df, s1_df), "S6_S1_Model")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 20)                2400
#
#  dense (Dense)               (None, 9)                 189
#
# =================================================================
# Total params: 2,589
# Trainable params: 2,589
# Non-trainable params: 0
# _________________________________________________________________
# <keras.engine.sequential.Sequential object at 0x7b22c27ecbb0>

# %%
y_pred_6_1_s, y_pred_6_1_uns = getPredictions(mergeDfs(s6_df, s1_df), s6_s1_model)
# Out:
# 15057/15057 [==============================] - 31s 2ms/step

# %%
y_pred_1_s = y_pred_6_1_s[:, -s1_df.shape[1]:]
y_pred_1_uns = y_pred_6_1_uns[:, -s1_df.shape[1]:]
s1_df_pred = pd.DataFrame(y_pred_1_uns, columns=['FIT101', 'LIT101', 'MV101', 'P101', 'P102'])
print(s1_df_pred)
# Out:
#           FIT101      LIT101     MV101      P101      P102
# 0       2.625566  653.856201  2.024834  2.014973  0.998660
# 1       2.610080  654.393799  2.024357  2.015734  0.998975
# 2       2.595160  654.865540  2.024091  2.016704  0.999172
# 3       2.577323  655.043030  2.023836  2.018118  0.999228
# 4       2.557962  655.106812  2.023326  2.019427  0.999407
# ...          ...         ...       ...       ...       ...
# 481790  2.507951  522.845215  2.001155  2.004842  1.000341
# 481791  2.495553  522.981567  2.000528  2.005219  1.000609
# 481792  2.484726  523.038086  1.999933  2.005623  1.000780
# 481793  2.473637  523.025818  1.999324  2.006081  1.000913
# 481794  2.464032  523.044006  1.998721  2.006356  1.001109
#
# [481795 rows x 5 columns]

# %%
print(s1_df)
# Out:
#           FIT101    LIT101  MV101  P101  P102
# 15000   2.670147  651.2425      2     2     1
# 15001   2.643564  651.7136      2     2     1
# 15002   2.623387  651.9883      2     2     1
# 15003   2.609935  652.3023      2     2     1
# 15004   2.600327  652.4201      2     2     1
# ...          ...       ...    ...   ...   ...
# 496795  2.460366  523.0430      2     2     1
# 496796  2.448836  522.9645      2     2     1
# 496797  2.434744  522.8860      2     2     1
# 496798  2.428338  522.9252      2     2     1
# 496799  2.427057  522.8467      2     2     1
#
# [481800 rows x 5 columns]

# %% [markdown]
# ## Predict for Stage 2 using Stage 1 Predictions

# %%
s1_s2_model = trainModel(mergeDfs(s1_df_pred, s2_df), "S1_S2_Model")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 20)                2960
#
#  dense_1 (Dense)             (None, 16)                336
#
# =================================================================
# Total params: 3,296
# Trainable params: 3,296
# Non-trainable params: 0
# _________________________________________________________________
# <keras.engine.sequential.Sequential object at 0x7b22c3f59300>

# %%
y_pred_1_2_s, y_pred_1_2_uns = getPredictions(mergeDfs(s1_df, s2_df), s1_s2_model)
# Out:
# 15057/15057 [==============================] - 32s 2ms/step

# %%
y_pred_2_s = y_pred_1_2_s[:, -s2_df.shape[1]:]
y_pred_2_uns = y_pred_1_2_uns[:, -s2_df.shape[1]:]
s2_df_pred = pd.DataFrame(y_pred_2_uns, columns=['AIT201', 'AIT202', 'AIT203', 'FIT201', 'MV201', 'P201', 'P202', 'P203', 'P204', 'P205', 'P206'])
print(s2_df_pred)
# Out:
#             AIT201    AIT202      AIT203    FIT201     MV201      P201  \
# 0       262.261841  8.411646  477.359863  2.398288  1.916412  1.040790
# 1       262.263336  8.411992  477.626343  2.398876  1.917025  1.040824
# 2       262.264984  8.412291  477.956818  2.399436  1.918407  1.041004
# 3       262.266205  8.412459  478.527527  2.400971  1.920753  1.041255
# 4       262.266632  8.412469  478.908661  2.402397  1.923085  1.041601
# ...            ...       ...         ...       ...       ...       ...
# 481790  261.612579  8.434898  324.021332  2.540412  2.019436  1.052408
# 481791  261.612976  8.435423  324.098206  2.540055  2.019809  1.052400
# 481792  261.616364  8.435846  324.213989  2.539911  2.020530  1.052432
# 481793  261.623077  8.436189  324.447815  2.540464  2.021495  1.052480
# 481794  261.627258  8.436357  324.514679  2.540589  2.022078  1.052546
#
#             P202      P203      P204      P205      P206
# 0       0.976407  1.985973  0.937295  0.900826  1.003995
# 1       0.976326  1.985666  0.937418  0.900810  1.004221
# 2       0.976299  1.985478  0.937436  0.900545  1.004412
# 3       0.976278  1.985938  0.937286  0.899917  1.004497
# 4       0.976192  1.985806  0.937233  0.899458  1.004721
# ...          ...       ...       ...       ...       ...
# 481790  0.982820  1.980870  0.965824  1.862889  1.010983
# 481791  0.982734  1.980474  0.965941  1.863527  1.011250
# 481792  0.982697  1.980282  0.966017  1.863978  1.011466
# 481793  0.982689  1.980491  0.966075  1.864192  1.011579
# 481794  0.982640  1.980316  0.966171  1.864542  1.011773
#
# [481795 rows x 11 columns]

# %%
print(s2_df)
# Out:
#           AIT201    AIT202    AIT203    FIT201  MV201  P201  P202  P203  P204  \
# 15000   262.2404  8.386824  495.0269  2.471022      2     1     1     2     1
# 15001   262.2404  8.386824  494.6680  2.471022      2     1     1     2     1
# 15002   262.2404  8.386824  494.6680  2.471022      2     1     1     2     1
# 15003   262.2404  8.386824  494.6680  2.471022      2     1     1     2     1
# 15004   262.2404  8.388105  494.3860  2.471022      2     1     1     2     1
# ...          ...       ...       ...       ...    ...   ...   ...   ...   ...
# 496795  262.0161  8.396437  328.5055  2.442316      2     1     1     2     1
# 496796  262.0161  8.396437  328.5055  2.442316      2     1     1     2     1
# 496797  262.0161  8.396437  328.6337  2.444879      2     1     1     2     1
# 496798  262.0161  8.396437  328.6337  2.445391      2     1     1     2     1
# 496799  262.0161  8.396437  328.6337  2.445391      2     1     1     2     1
#
#         P205  P206
# 15000      1     1
# 15001      1     1
# 15002      1     1
# 15003      1     1
# 15004      1     1
# ...      ...   ...
# 496795     2     1
# 496796     2     1
# 496797     2     1
# 496798     2     1
# 496799     2     1
#
# [481800 rows x 11 columns]

# %% [markdown]
# ## Predict for Stage 3 using Stage 2 Predictions

# %%
s2_s3_model = trainModel(mergeDfs(s2_df_pred, s3_df), "S2_S3_Model")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 20)                3200
#
#  dense_2 (Dense)             (None, 19)                399
#
# =================================================================
# Total params: 3,599
# Trainable params: 3,599
# Non-trainable params: 0
# _________________________________________________________________
# <keras.engine.sequential.Sequential object at 0x7b22c3e69f60>

# %%
y_pred_2_3_s, y_pred_2_3_uns = getPredictions(mergeDfs(s2_df, s3_df), s2_s3_model)
# Out:
# 15057/15057 [==============================] - 31s 2ms/step

# %%
y_pred_3_s = y_pred_2_3_s[:, -s3_df.shape[1]:]
y_pred_3_uns = y_pred_2_3_uns[:, -s3_df.shape[1]:]
s3_df_pred = pd.DataFrame(y_pred_3_uns, columns=['FIT301', 'LIT301', 'MV301', 'MV302', 'MV303', 'MV304', 'P301', 'P302'])
print(s3_df_pred)
# Out:
#           FIT301      LIT301     MV301     MV302     MV303     MV304  \
# 0       1.781012  959.762207  1.298694  2.094172  1.105765  0.840209
# 1       1.781220  959.734131  1.298385  2.094201  1.105346  0.840031
# 2       1.781066  959.616699  1.298393  2.094339  1.105399  0.840266
# 3       1.780859  959.554749  1.298461  2.094523  1.105536  0.840400
# 4       1.780635  959.673279  1.298535  2.094728  1.105905  0.840266
# ...          ...         ...       ...       ...       ...       ...
# 481790  2.049734  965.407654  1.177440  1.988957  1.204564  0.779900
# 481791  2.049857  965.479919  1.177340  1.988924  1.204593  0.779795
# 481792  2.049393  965.465881  1.177431  1.988940  1.204590  0.780009
# 481793  2.048491  965.471619  1.177696  1.988774  1.204357  0.780608
# 481794  2.047584  965.583130  1.177829  1.988701  1.204078  0.780875
#
#             P301      P302
# 0       0.939091  1.920407
# 1       0.939144  1.920557
# 2       0.939189  1.920760
# 3       0.939196  1.920880
# 4       0.939099  1.920835
# ...          ...       ...
# 481790  0.971530  1.973537
# 481791  0.971566  1.973692
# 481792  0.971551  1.973752
# 481793  0.971510  1.973771
# 481794  0.971471  1.973715
#
# [481795 rows x 8 columns]

# %%
print(s3_df)
# Out:
#           FIT301    LIT301  MV301  MV302  MV303  MV304  P301  P302
# 15000   2.043237  977.5538      1      2      1      1     1     2
# 15001   2.044903  977.6740      1      2      1      1     1     2
# 15002   2.044903  977.4738      1      2      1      1     1     2
# 15003   2.044903  977.6340      1      2      1      1     1     2
# 15004   2.044903  977.5538      1      2      1      1     1     2
# ...          ...       ...    ...    ...    ...    ...   ...   ...
# 496795  2.212087  955.8046      1      2      1      1     1     2
# 496796  2.210037  955.8847      1      2      1      1     1     2
# 496797  2.207731  955.9648      1      2      1      1     1     2
# 496798  2.206835  956.2051      1      2      1      1     1     2
# 496799  2.206835  956.1651      1      2      1      1     1     2
#
# [481800 rows x 8 columns]

# %% [markdown]
# ## Predict for Stage 4 using Stage 3 Predictions

# %%
s3_s4_model = trainModel(mergeDfs(s3_df_pred, s4_df), "S3_S4_Model")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 20)                3040
#
#  dense_3 (Dense)             (None, 17)                357
#
# =================================================================
# Total params: 3,397
# Trainable params: 3,397
# Non-trainable params: 0
# _________________________________________________________________
# <keras.engine.sequential.Sequential object at 0x7b22d60cba30>

# %%
y_pred_3_4_s, y_pred_3_4_uns = getPredictions(mergeDfs(s3_df, s4_df), s3_s4_model)
# Out:
# 15057/15057 [==============================] - 31s 2ms/step

# %%
y_pred_4_s = y_pred_3_4_s[:, -s4_df.shape[1]:]
y_pred_4_uns = y_pred_3_4_uns[:, -s4_df.shape[1]:]
s4_df_pred = pd.DataFrame(y_pred_4_uns, columns=['AIT401', 'AIT402', 'FIT401', 'LIT401', 'P401', 'P402', 'P403', 'P404', 'UV401'])
print(s4_df_pred)
# Out:
#             AIT401      AIT402    FIT401      LIT401      P401      P402  \
# 0        -7.544950  196.109344  1.701765  838.661011  1.035559  2.021986
# 1        -7.486716  196.122192  1.701567  838.791260  1.035723  2.022187
# 2        -7.454515  196.118652  1.701422  838.795532  1.035981  2.022407
# 3        -7.451478  196.132751  1.701422  838.754639  1.035949  2.022383
# 4        -7.291423  196.128113  1.701900  838.923462  1.036151  2.023250
# ...            ...         ...       ...         ...       ...       ...
# 481790  145.694153  156.452423  1.717749  947.132874  1.048218  2.016400
# 481791  145.653992  156.478806  1.717096  946.931458  1.048204  2.016529
# 481792  145.703156  156.471954  1.716620  947.039612  1.048194  2.016812
# 481793  145.767471  156.452408  1.716294  947.292480  1.048271  2.017150
# 481794  145.533737  156.495514  1.715393  947.173035  1.048759  2.017072
#
#             P403      P404     UV401
# 0       0.989828  0.990986  2.001910
# 1       0.989948  0.990780  2.001796
# 2       0.990037  0.990642  2.001690
# 3       0.990070  0.990594  2.001693
# 4       0.990245  0.990814  2.001198
# ...          ...       ...       ...
# 481790  0.984362  0.999448  2.007872
# 481791  0.984513  0.999359  2.007762
# 481792  0.984914  0.999071  2.007569
# 481793  0.985286  0.998749  2.007344
# 481794  0.984817  0.998666  2.007497
#
# [481795 rows x 9 columns]

# %%
print(s4_df)
# Out:
#          AIT401    AIT402    FIT401    LIT401  P401  P402  P403  P404  UV401
# 15000     0.000  197.1546  1.701855  827.8646     1     2     1     1      2
# 15001     0.000  197.1546  1.701855  827.6724     1     2     1     1      2
# 15002     0.000  197.1546  1.700061  828.1722     1     2     1     1      2
# 15003     0.000  197.2827  1.700061  828.1338     1     2     1     1      2
# 15004     0.000  197.2827  1.700061  828.2491     1     2     1     1      2
# ...         ...       ...       ...       ...   ...   ...   ...   ...    ...
# 496795  148.808  156.0882  1.715439  941.8354     1     2     1     1      2
# 496796  148.808  156.0882  1.715439  941.9893     1     2     1     1      2
# 496797  148.808  156.0882  1.715439  942.1815     1     2     1     1      2
# 496798  148.808  156.0882  1.713517  941.9508     1     2     1     1      2
# 496799  148.808  156.0882  1.713517  942.0662     1     2     1     1      2
#
# [481800 rows x 9 columns]

# %% [markdown]
# ## Predict for Stage 5 using Stage 4 Predictions

# %%
s4_s5_model = trainModel(mergeDfs(s4_df_pred, s5_df), "S4_S5_Model")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 20)                3440
#
#  dense_4 (Dense)             (None, 22)                462
#
# =================================================================
# Total params: 3,902
# Trainable params: 3,902
# Non-trainable params: 0
# _________________________________________________________________
# <keras.engine.sequential.Sequential object at 0x7b22ade3b310>

# %%
y_pred_4_5_s, y_pred_4_5_uns = getPredictions(mergeDfs(s4_df, s5_df), s4_s5_model)
# Out:
# 15057/15057 [==============================] - 32s 2ms/step

# %%
y_pred_5_s = y_pred_4_5_s[:, -s5_df.shape[1]:]
y_pred_5_uns = y_pred_4_5_uns[:, -s5_df.shape[1]:]
s5_df_pred = pd.DataFrame(y_pred_5_uns, columns=['AIT501', 'AIT502', 'AIT503', 'AIT504', 'FIT501', 'FIT502', 'FIT503', 'FIT504', 'P501', 'P502', 'PIT501', 'PIT502', 'PIT503'])
print(s5_df_pred)
# Out:
#           AIT501      AIT502      AIT503     AIT504    FIT501    FIT502  \
# 0       7.846036  179.233170  269.978424  11.672408  1.703894  1.259332
# 1       7.845654  179.350281  270.249786  11.673306  1.703808  1.258083
# 2       7.846292  179.652084  270.401245  11.669559  1.703748  1.257969
# 3       7.847057  179.799881  270.329071  11.667617  1.703858  1.259008
# 4       7.848085  179.468750  270.198456  11.689288  1.703938  1.262456
# ...          ...         ...         ...        ...       ...       ...
# 481790  7.860103  149.901642  264.308777  12.119129  1.711229  1.287760
# 481791  7.859829  149.901276  264.399536  12.122587  1.711110  1.286299
# 481792  7.858915  150.085068  264.582886  12.085327  1.710497  1.281296
# 481793  7.858453  150.357300  264.798492  12.047981  1.709859  1.276781
# 481794  7.858508  150.643951  264.808563  12.032733  1.709504  1.275106
#
#           FIT503    FIT504      P501      P502      PIT501    PIT502  \
# 0       0.739080  0.309097  2.011372  0.969023  252.866852  1.685677
# 1       0.739691  0.309092  2.011436  0.968289  252.973602  1.682358
# 2       0.739969  0.309122  2.012968  0.968516  253.041824  1.681870
# 3       0.739736  0.309095  2.013545  0.968763  253.050278  1.674335
# 4       0.739590  0.309026  2.014009  0.968126  253.083069  1.632080
# ...          ...       ...       ...       ...         ...       ...
# 481790  0.733956  0.306197  2.050246  0.966297  250.608994  1.698776
# 481791  0.734041  0.306268  2.050418  0.967713  250.560989  1.726464
# 481792  0.734210  0.306379  2.052613  0.970752  250.599167  1.745840
# 481793  0.734348  0.306444  2.055035  0.972925  250.664261  1.757119
# 481794  0.734285  0.306444  2.056427  0.972557  250.648514  1.728576
#
#             PIT503
# 0       192.030914
# 1       192.177734
# 2       192.291855
# 3       192.304962
# 4       192.347809
# ...            ...
# 481790  189.326843
# 481791  189.263901
# 481792  189.234314
# 481793  189.251724
# 481794  189.234268
#
# [481795 rows x 13 columns]

# %%
print(s5_df)
# Out:
#           AIT501    AIT502    AIT503    AIT504    FIT501    FIT502    FIT503  \
# 15000   7.857793  184.0041  274.4168  12.22763  1.710331  1.272576  0.739750
# 15001   7.857793  184.0041  274.4168  12.22763  1.710331  1.271679  0.739750
# 15002   7.857793  184.0041  274.4168  12.22763  1.710331  1.271679  0.739750
# 15003   7.857793  184.0041  274.4168  12.22763  1.710331  1.278468  0.739750
# 15004   7.857793  184.0041  274.5450  12.22763  1.710331  1.272320  0.739750
# ...          ...       ...       ...       ...       ...       ...       ...
# 496795  7.878621  145.2704  264.5475  12.03538  1.726352  1.292430  0.735269
# 496796  7.878621  145.2704  264.5475  12.03538  1.724942  1.281158  0.735269
# 496797  7.878621  145.2704  264.5475  12.03538  1.723789  1.272576  0.735269
# 496798  7.878621  145.1166  264.5475  12.03538  1.723789  1.272576  0.735269
# 496799  7.878621  145.1166  264.5475  12.03538  1.723789  1.279621  0.735269
#
#           FIT504  P501  P502    PIT501    PIT502    PIT503
# 15000   0.310604     2     1  253.4286  1.361612  192.6589
# 15001   0.310604     2     1  253.4286  1.361612  192.6589
# 15002   0.309067     2     1  253.4286  1.361612  192.6589
# 15003   0.308619     2     1  253.4286  1.361612  192.6589
# 15004   0.308619     2     1  253.4286  1.361612  192.6589
# ...          ...   ...   ...       ...       ...       ...
# 496795  0.308619     2     1  250.8171  1.778105  189.8552
# 496796  0.308619     2     1  250.8171  1.778105  189.5027
# 496797  0.308619     2     1  250.8171  1.778105  189.5027
# 496798  0.308619     2     1  250.8171  1.649953  189.5027
# 496799  0.307786     2     1  250.8652  1.649953  189.5988
#
# [481800 rows x 13 columns]

# %% [markdown]
# ## Predict for Stage 6 using Stage 5 Predictions

# %%
s5_s6_model = trainModel(mergeDfs(s5_df_pred, s6_df), "S5_S6_Model")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 20)                3040
#
#  dense_5 (Dense)             (None, 17)                357
#
# =================================================================
# Total params: 3,397
# Trainable params: 3,397
# Non-trainable params: 0
# _________________________________________________________________
# <keras.engine.sequential.Sequential object at 0x7b22db8b9540>

# %%
y_pred_5_6_s, y_pred_5_6_uns = getPredictions(mergeDfs(s5_df, s6_df), s5_s6_model)
# Out:
# 15057/15057 [==============================] - 31s 2ms/step

# %%
y_pred_6_s = y_pred_5_6_s[:, -s6_df.shape[1]:]
y_pred_6_uns = y_pred_5_6_uns[:, -s6_df.shape[1]:]
s6_df_pred = pd.DataFrame(y_pred_6_uns, columns=['FIT601', 'P601', 'P602', 'P603'])
print(s6_df_pred)
# Out:
#           FIT601      P601      P602      P603
# 0      -0.006139  1.010129  1.042654  1.005481
# 1      -0.004964  1.008695  1.037659  1.005132
# 2      -0.008494  1.010313  1.033703  1.004610
# 3      -0.015772  1.011661  1.032091  1.003851
# 4      -0.020791  1.007215  1.026434  1.000357
# ...          ...       ...       ...       ...
# 481790 -0.046288  0.961592  0.997473  1.033359
# 481791 -0.053408  0.964357  0.996420  1.036844
# 481792 -0.048335  0.967690  1.000914  1.036919
# 481793 -0.037923  0.969645  1.007360  1.035469
# 481794 -0.030026  0.968779  1.010607  1.032840
#
# [481795 rows x 4 columns]

# %%
print(s6_df)
# Out:
#           FIT601  P601  P602  P603
# 15000   0.000128     1     1     1
# 15001   0.000128     1     1     1
# 15002   0.000128     1     1     1
# 15003   0.000128     1     1     1
# 15004   0.000128     1     1     1
# ...          ...   ...   ...   ...
# 496795  0.000128     1     1     1
# 496796  0.000128     1     1     1
# 496797  0.000128     1     1     1
# 496798  0.000128     1     1     1
# 496799  0.000128     1     1     1
#
# [481800 rows x 4 columns]
